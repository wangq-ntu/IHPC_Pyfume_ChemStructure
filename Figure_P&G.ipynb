# %% [markdown]
# # Pyfume_ChemStructure Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !cp /content/drive/MyDrive/DOS_0.25n/Helvetica-Font/Helvetica.ttf /usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.pyplot as plt
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=20)

# %%
# label
label=pd.read_csv('/content/drive/MyDrive/pgml/Data analysis/common/update17jan/train/label_502.csv')
#label=pd.read_csv(path+'com_label_169.csv')
label=label.drop(columns=['CommonCID'])
y=label

# %% [markdown]
# Word Clond

# %%
from wordcloud import WordCloud
from wordcloud import WordCloud, ImageColorGenerator

nonzero_counts = label.apply(lambda col: (col != 0).sum())
label_a = label.loc[:, nonzero_counts >= 2]
word_frequencies = label_a.sum().to_dict()
# Combine all text entries into a single string
text_combined = ' '.join(label_a.columns)
#bubble_mask = imageio.imread(r"/content/Top-Anecdotal-signs-of-a-market-bubble-1.png")
# Generate the word cloud
wordcloud = WordCloud( font_path='/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',mode='RGB',random_state = 42,background_color='white',contour_width=1,contour_color='steelblue').generate_from_frequencies(word_frequencies)
#colormap='Accent'
# Display the generated word cloud
plt.figure(figsize=(10, 5))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
# store to file
#plt.savefig("twitter.png", format="png")
plt.show()

# %%
font=50
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=font)
myfont1 = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=45)
nonzero_counts = label.apply(lambda col: (col != 0).sum())
label_a = label.loc[:, nonzero_counts >= 2]
nonzero_counts = label_a.apply(lambda col: (col != 0).sum())
nonzero=nonzero_counts.to_frame(name ='Count')
new_sort=nonzero.sort_values(by=['Count'],ascending=False)
width=0.9
fig, ax = plt.subplots()
fig.set_figwidth(85)
fig.set_figheight(30)
#new_sort.plot(kind='bar', color='#189A80')
new_sort.plot.bar( rot=80, width=width, ax=ax,color='#189A80',)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for spine in ax.spines.values():
    spine.set_linewidth(4)
    spine.set_color('k')
    spine.set_linestyle('-')
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=15)
ax.tick_params(which='minor', length=4)
#ax.tick_params(axis='both',width=4, length=10)
ax.get_legend().remove()
plt.xlabel('Odors',rotation=0,fontproperties=myfont)
plt.ylabel('Numbber of Compounds',fontproperties=myfont,weight='bold',rotation=90)
#plt.title('Counts of Nonzero Values in Columns',fontproperties=myfont, weight='bold')
plt.xticks(rotation='vertical',fontproperties=myfont1)
plt.yticks(fontproperties=myfont)
plt.show()

# %% [markdown]
# # PERFORMACE compare

# %%
# read excel
#C:\wq\P&GML\capsuleml\dataset\data_analysis\figure
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/pgml/figure/perfomace3a.xlsx')
# rename first colum
df.rename(columns={'Unnamed: 0': 'Name'}, inplace=True)
df
# Out:
#               Name  Our Work (RF)  Anju Sharma (RF+PPMF)  \
# 0  ROC_AUC (macro)         0.7184                  0.682
# 1  ROC_AUC (micro)         0.8470                  0.456
# 2         F1-score         0.3100                  0.290
# 3           Recall         0.3300                  0.500
# 4        Precision         0.2900                  0.630
#
#    Anju Sharma (DNN+PPMF)  Saini (Binary relevance +Daylight)  \
# 0                   0.753                              0.0000
# 1                   0.784                              0.0000
# 2                   0.520                              0.3319
# 3                   0.460                              0.3400
# 4                   0.710                              0.3500
#
#    Sanchez-Lengelinga(GNN)  Sanchez-Lengelinga(RF+Mordred)
# 0                    0.894                           0.845
# 1                    0.000                           0.000
# 2                    0.360                           0.300
# ...

# %%
ROC_AUC (macro)
ROC_AUC (micro)
F1-score
Recall
Precision
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cb6c00c943fd> in <cell line: 1>()
# ----> 1 ROC_AUC (macro)
#       2 ROC_AUC (micro)
#       3 F1-score
#       4 Recall
#       5 Precision
#
# NameError: name 'ROC_AUC' is not defined

# %%
# Create a figure and axis object
# %matplotlib
# %pylab inline
font=55
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=font)

myfont1 = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=40)

fig, ax = plt.subplots(figsize =(22, 16))
# Define custom colors for each bar
colors = ['#D24132', '#189A80', '#F09C2A', '#73ABCF','#189A80','skyblue']

# Plot the data
df.set_index('Name').plot(kind='bar',width = 0.6, ax=ax,color=colors)

# Adjust the spacing between subplots
plt.tight_layout()

# Add labels and title
#ax.set_xlabel('Metrics',fontproperties=myfont)
ax.set_ylabel('Performace',fontproperties=myfont,labelpad=20)
#ax.set_title('Multi-label classfication',fontproperties=myfont)
tick_labels = ['ROC_AUC\n(macro)', 'ROC_AUC\n(micro)', 'F1-score', 'Recall', 'Precision']
# Rotate the x-axis labels for better visibility
# Get the current tick locations
ticks = ax.get_xticks()
plt.xticks(ticks, labels=tick_labels, fontproperties=myfont)
plt.yticks(fontproperties=myfont)
plt.legend(frameon=False,prop=myfont1,bbox_to_anchor=(0.30,0.59))
plt.ylim(0,1)
ax.tick_params(axis='both',width=4, length=10)
ax.spines['bottom'].set_linewidth(4)
ax.spines['left'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
# Display the plot
plt.show()
# Out:
# Using matplotlib backend: <object object at 0x7ea1ecdeba70>
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['nonzero']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# # function nation group

# %%
from matplotlib.ticker import FormatStrFormatter
from matplotlib.font_manager import FontProperties
import pandas as pd
import matplotlib.pyplot as plt

font=30
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font)

# Load data from files
def load_data(file_path):
    with open(file_path, 'r') as raw_data:
        data = [line.strip().split() for line in raw_data.readlines()]
    x_list = [record[0] for record in data]
    y_list = [int(record[1]) for record in data]  # Convert y values to int
    return pd.DataFrame({'FG Category': x_list, 'Count': y_list})

df1 = load_data('/content/FG_pattern_count_table_arc.txt')
df2 = load_data('/content/FG_pattern_count_table_leff.txt')
df3 = load_data('/content/FG_pattern_count_table sig.txt')

# Create subplots
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(20, 38))
width = 0.75

# Plot each DataFrame
df1.plot.bar(x='FG Category', y='Count', rot=80, width=width, ax=ax1,color='#D24132',label='Arctander')
ax1.set_ylabel('Count', fontproperties=myfont, labelpad=20)
ax1.set_xticklabels(df1['FG Category'],fontproperties=myfont)
ax1.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax1.set_xlabel('')  # Remove x-axis title
ax1.set_yticklabels([f'{tick:.2f}' for tick in ax1.get_yticks()], fontproperties=myfont)
ax1.legend(prop=myfont, frameon=False)
ax1.tick_params(which='both', width=2)
ax1.tick_params(which='major', length=8)
ax1.tick_params(which='minor', length=4)
ax1.grid(False)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
for spine in ax1.spines.values():
    spine.set_linewidth(3)
    spine.set_color('k')
    spine.set_linestyle('-')

df2.plot.bar(x='FG Category', y='Count', rot=80, width=width, ax=ax2,color='#189A80',label='Leffingwell')
ax2.set_ylabel('Count', fontproperties=myfont, labelpad=20)
ax2.set_xlabel('')  # Remove x-axis title
ax2.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax2.set_yticklabels([f'{tick:.2f}' for tick in ax2.get_yticks()], fontproperties=myfont)
ax2.set_xticklabels(df2['FG Category'],fontproperties=myfont)
ax2.legend(prop=myfont, frameon=False)
ax2.tick_params(which='both', width=2)
ax2.tick_params(which='major', length=8)
ax2.tick_params(which='minor', length=4)
ax2.grid(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
for spine in ax2.spines.values():
    spine.set_linewidth(3)
    spine.set_color('k')
    spine.set_linestyle('-')

df3.plot.bar(x='FG Category', y='Count', rot=80, width=width, ax=ax3,color='#F09C2A',label='Sigma')
ax3.set_ylabel('Count', fontproperties=myfont, labelpad=20)
ax3.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax3.set_yticklabels([f'{tick:.2f}' for tick in ax3.get_yticks()], fontproperties=myfont)
ax3.set_xticklabels(df3['FG Category'],fontproperties=myfont)
ax3.set_xlabel('')  # Remove x-axis title
ax3.legend(prop=myfont, frameon=False)
ax3.tick_params(which='both', width=2)
ax3.tick_params(which='major', length=8)
ax3.tick_params(which='minor', length=4)
ax3.grid(False)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
for spine in ax3.spines.values():
    spine.set_linewidth(3)
    spine.set_color('k')
    spine.set_linestyle('-')

# Adjust layout and display
plt.subplots_adjust(hspace=0.75)  # Adjust this value as needed
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-8a0e2ffc52b4> in <cell line: 17>()
#      15     return pd.DataFrame({'FG Category': x_list, 'Count': y_list})
#      16
# ---> 17 df1 = load_data('/content/FG_pattern_count_table_arc.txt')
#      18 df2 = load_data('/content/FG_pattern_count_table_leff.txt')
#      19 df3 = load_data('/content/FG_pattern_count_table sig.txt')
#
# <ipython-input-9-8a0e2ffc52b4> in load_data(file_path)
#       9 # Load data from files
#      10 def load_data(file_path):
# ---> 11     with open(file_path, 'r') as raw_data:
#      12         data = [line.strip().split() for line in raw_data.readlines()]
#      13     x_list = [record[0] for record in data]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/FG_pattern_count_table_arc.txt'

# %% [markdown]
# ### score per label

# %%
def read_txt(file_path):
    with open(file_path, 'r') as file:
        content = file.read().splitlines()
    return content

class_names = read_txt('/content/drive/MyDrive/pgml/figure/class_names.txt')
print(class_names)
# Out:
# ['alcohol', 'aldehidic', 'almond', 'beefy', 'butter', 'cheesey', 'citrus', 'coco', 'coumarin', 'ehtereal', 'floral', 'fruity', 'garlic', 'green', 'jasmin', 'leather', 'lilac', 'mint', 'mushroom', 'musky', 'musty', 'peach', 'pepper', 'pine', 'rooty', 'sulfuraceous', 'vanillin', 'wood', 'aromatic', 'orange', 'gas', 'rose', 'milky', 'balsamic', 'camphoreous', 'caramelic', 'herbal', 'winey', 'acid', 'ambre', 'animal', 'anisic', 'apple', 'apricot', 'banana', 'berry', 'brandy', 'creamy', 'earthy', 'fatty', 'gassy', 'geranium', 'grape', 'hay', 'honey', 'hyacinth', 'leafy', 'lily', 'medicinal', 'metallic', 'mimosa', 'mossy', 'narcissus', 'nut', 'nutty', 'oily', 'orris', 'pear', 'phenolic', 'pineapple', 'plum', 'powdery', 'sandalwood', 'smoky', 'sour', 'spicy', 'tarry', 'tea', 'tobacco', 'vanilla', 'violet', 'waxy', 'alliaceous', 'black currant', 'bread', 'brothy', 'burnt', 'cabbage', 'catty', 'chamomile', 'cherry', 'chicken', 'chocolate', 'cinnamon', 'cocoa', 'coffee', 'cognac', 'cucumber', 
# ...

# %%
score=pd.read_csv('/content/drive/MyDrive/pgml/figure/scores.csv')
score
# Out:
#      f1_score    recall
# 0    0.589520  0.584416
# 1    0.545455  0.500000
# 2    0.501425  0.611111
# 3    0.461538  0.400000
# 4    0.447222  0.470760
# ..        ...       ...
# 146  0.000000  0.000000
# 147  0.000000  0.000000
# 148  0.000000  0.000000
# 149  0.000000  0.000000
# 150  0.000000  0.000000
#
# [151 rows x 2 columns]

# %%
f1_score=score['f1_score']
recall=score['recall']
f1_score_sorted=score['f1_score'].sort_values(ascending=False)
recall_sorted=score['recall'].sort_values(ascending=False)

# %%
font=25
font1=25
myfont1 = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=font1)
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=font)
# items to be removed
unwanted_num = {"micro avg",'macro avg','weighted avg','samples avg'}

class_names= [ele for ele in class_names if ele not in unwanted_num]

# Extract precision, recall, and F1-score for each class

#recall = [score[class_name]['recall'] for class_name in class_names]
#f1_score = [score[class_name]['f1-score'] for class_name in class_names]

# # Sort precision, recall, and F1-score in descending order
sorted_indices = sorted(range(len(f1_score)), key=lambda k: (f1_score[k],recall[k]), reverse=True)
#recall_sorted = [recall[i] for i in sorted_indices]
#f1_score_sorted = [f1_score[i] for i in sorted_indices]




# Create the bar chart (similar to your existing code)
#plt.figure(figsize=(18, 6))
fig, ax = plt.subplots(figsize =(30,10))
# Define width for the bars
width = 0.4

index = range(len(class_names))
bar1 = plt.bar([p + 2 * width for p in index], f1_score_sorted, width, label='F1-Score',color='#ECC97F',edgecolor='#ECC97F')
bar2 = plt.bar([p + width for p in index], recall_sorted, width, label='Recall',color='skyblue',edgecolor='skyblue')
#bar3 = plt.bar(index, precision_sorted, width, label='Precision')


plt.xlabel('Smell',fontproperties=myfont)
plt.ylabel('Performance Score',fontproperties=myfont)
#plt.title('Random Forest Model',fontproperties=myfont)
plt.xticks([p + 1.5 * width for p in index], [class_names[i] for i in sorted_indices])
plt.xticks(rotation=90,fontproperties=myfont1)
plt.yticks(fontproperties=myfont,rotation=90)
ax.tick_params(which='both', width=2)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=4)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
plt.xlim(-1,95)
#legend =plt.legend(prop=myfont)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from matplotlib.font_manager import FontProperties

# Font setup
font1 = 25
myfont1 = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font1)
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font1)

# Remove unwanted categories
unwanted_num = {"micro avg", 'macro avg', 'weighted avg', 'samples avg'}
class_names = [ele for ele in class_names if ele not in unwanted_num]

# Sort by F1-score first, then by recall for ties
sorted_indices = sorted(range(len(f1_score)), key=lambda k: (f1_score[k], recall[k]), reverse=True)
f1_score_sorted = [f1_score[i] for i in sorted_indices]
recall_sorted = [recall[i] for i in sorted_indices]
class_names_sorted = [class_names[i] for i in sorted_indices]

# Setup color gradients - using Blues colormap for a light-to-dark effect
cmap_f1 = plt.cm.Blues  # Changed to Blues for better light-to-dark progression
cmap_recall = plt.cm.Oranges  # Changed to Oranges for contrast

# Normalize values for color mapping
norm_f1 = Normalize(vmin=min(f1_score_sorted), vmax=max(f1_score_sorted))
norm_recall = Normalize(vmin=min(recall_sorted), vmax=max(recall_sorted))

# Create ScalarMappable for colorbars
sm_f1 = ScalarMappable(cmap=cmap_f1, norm=norm_f1)
sm_f1.set_array([])
sm_recall = ScalarMappable(cmap=cmap_recall, norm=norm_recall)
sm_recall.set_array([])

# Create the visualization
fig, ax = plt.subplots(figsize=(34, 13))
width = 0.5
index = range(len(class_names))

# Generate colors for bars
bar_colors_f1 = [cmap_f1(norm_f1(score)) for score in f1_score_sorted]
bar_colors_recall = [cmap_recall(norm_recall(score)) for score in recall_sorted]

# Create bars
bar1 = plt.bar([p + 2 * width for p in index], f1_score_sorted, width,
               label='F1-Score', color=bar_colors_f1, edgecolor='black', linewidth=0.5)
bar2 = plt.bar([p + width for p in index], recall_sorted, width,
               label='Recall', color=bar_colors_recall, edgecolor='black', linewidth=0.5)

# Add colorbars
cbar_f1 = plt.colorbar(sm_f1, ax=ax, orientation='vertical', fraction=0.02, pad=0.1)
cbar_f1.ax.tick_params(labelsize=25)
for label in cbar_f1.ax.get_yticklabels():
    label.set_fontproperties(myfont)
cbar_f1.set_label('F1-Score Gradient', fontproperties=myfont)
cbar_recall = plt.colorbar(sm_recall, ax=ax, orientation='vertical', fraction=0.02, pad=0.1)
cbar_recall.set_label('Recall Gradient', fontproperties=myfont)
cbar_recall.ax.tick_params(labelsize=25)
for label in cbar_recall.ax.get_yticklabels():
    label.set_fontproperties(myfont)
# Customize the plot
plt.xlabel('Smell', fontproperties=myfont)
plt.ylabel('Performance Score', fontproperties=myfont)
plt.xticks([p + 1.5 * width for p in index], class_names_sorted, rotation=90, fontproperties=myfont1)
plt.yticks(fontproperties=myfont)

# Adjust tick parameters and spines
ax.tick_params(which='both', width=2)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=4)
for spine in ax.spines.values():
    spine.set_linewidth(2)

plt.xlim(-1, 95)
#plt.legend(prop=myfont)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

font1 = 25
myfont1 = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font1)
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font1)

# Items to be removed
unwanted_num = {"micro avg", 'macro avg', 'weighted avg', 'samples avg'}

class_names = [ele for ele in class_names if ele not in unwanted_num]

# Extract precision, recall, and F1-score for each class
# Assuming recall and f1_score are already calculated
sorted_indices = sorted(range(len(f1_score)), key=lambda k: (f1_score[k], recall[k]), reverse=True)
recall_sorted = [recall[i] for i in sorted_indices]
f1_score_sorted = [f1_score[i] for i in sorted_indices]

# Gradient setup for F1-Score and Recall
cmap_f1 = plt.cm.summer_r  # Reversed colormap for F1-Score
cmap_recall = plt.cm.cividis_r  # Reversed colormap for Recall
norm_f1 = Normalize(vmin=min(f1_score_sorted), vmax=max(f1_score_sorted))
norm_recall = Normalize(vmin=min(recall_sorted), vmax=max(recall_sorted))

# Create ScalarMappable for colorbars
sm_f1 = ScalarMappable(cmap=cmap_f1, norm=norm_f1)
sm_f1.set_array([])
sm_recall = ScalarMappable(cmap=cmap_recall, norm=norm_recall)
sm_recall.set_array([])

# Create the bar chart
fig, ax = plt.subplots(figsize=(30, 10))
width = 0.5
index = range(len(class_names))

# Apply gradient colors to bars
bar_colors_f1 = [cmap_f1(norm_f1(score)) for score in f1_score_sorted]
bar_colors_recall = [cmap_recall(norm_recall(score)) for score in recall_sorted]

bar1 = plt.bar([p + 2 * width for p in index], f1_score_sorted, width, label='F1-Score', color=bar_colors_f1, edgecolor=bar_colors_f1)
bar2 = plt.bar([p + width for p in index], recall_sorted, width, label='Recall', color=bar_colors_recall, edgecolor=bar_colors_recall)

# Add colorbars for gradients
cbar_f1 = plt.colorbar(sm_f1, ax=ax, orientation='vertical', fraction=0.02, pad=0.01)
cbar_f1.set_label('F1-Score Gradient', fontproperties=myfont)
cbar_recall = plt.colorbar(sm_recall, ax=ax, orientation='vertical', fraction=0.02, pad=0.06)
cbar_recall.set_label('Recall Gradient', fontproperties=myfont)

# Add labels and styles
plt.xlabel('Smell', fontproperties=myfont)
plt.ylabel('Performance Score', fontproperties=myfont)
plt.xticks([p + 1.5 * width for p in index], [class_names[i] for i in sorted_indices], rotation=90, fontproperties=myfont1)
plt.yticks(fontproperties=myfont, rotation=90)
ax.tick_params(which='both', width=2)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=4)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
plt.xlim(-1, 95)
plt.legend(prop=myfont)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

font1 = 25
myfont1 = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font1)
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=font1)

# Items to be removed
unwanted_num = {"micro avg", 'macro avg', 'weighted avg', 'samples avg'}

class_names = [ele for ele in class_names if ele not in unwanted_num]

# Extract precision, recall, and F1-score for each class
# Assuming recall and f1_score are already calculated
sorted_indices = sorted(range(len(f1_score)), key=lambda k: (f1_score[k], recall[k]), reverse=True)
recall_sorted = [recall[i] for i in sorted_indices]
f1_score_sorted = [f1_score[i] for i in sorted_indices]

# Gradient setup with reversed colormap
cmap = plt.cm.viridis_r  # Use _r to reverse the colormap
norm = Normalize(vmin=min(f1_score_sorted), vmax=max(f1_score_sorted))
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

# Create the bar chart
fig, ax = plt.subplots(figsize=(30, 10))
width = 0.5
index = range(len(class_names))

# Apply gradient colors to bars
bar_colors = [cmap(norm(score)) for score in f1_score_sorted]

bar1 = plt.bar([p + 2 * width for p in index], f1_score_sorted, width, label='F1-Score', color=bar_colors, edgecolor=bar_colors)
bar2 = plt.bar([p + width for p in index], recall_sorted, width, label='Recall', color='skyblue', edgecolor='skyblue')

# Add colorbar for gradient
cbar = plt.colorbar(sm, ax=ax, orientation='vertical')
cbar.set_label('F1-Score Gradient', fontproperties=myfont)

# Add labels and styles
plt.xlabel('Smell', fontproperties=myfont)
plt.ylabel('Performance Score', fontproperties=myfont)
plt.xticks([p + 1.5 * width for p in index], [class_names[i] for i in sorted_indices], rotation=90, fontproperties=myfont1)
plt.yticks(fontproperties=myfont, rotation=90)
ax.tick_params(which='both', width=2)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=4)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
plt.xlim(-1,95)
plt.legend(prop=myfont)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## number of fweatures

# %%
f=pd.read_csv('/content/drive/MyDrive/pgml/figure/num_features_vs_f1_score2.csv')
f
# Out:
#     num_features  f1_scores_mean
# 0              1        0.140607
# 1             11        0.255197
# 2             21        0.255260
# 3             31        0.256505
# 4             41        0.253667
# 5             51        0.252929
# 6             61        0.252489
# 7             71        0.252240
# 8             81        0.252949
# 9             91        0.250934
# 10           101        0.246314
# 11           151        0.246726
# 12           201        0.242483
# 13           251        0.243330
# 14           301        0.241450
# 15           351        0.245440
# 16           401        0.245429
# 17           451        0.241983
# 18           501        0.245855

# %%
# prompt: plot f dot line

import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties

# Assuming 'f' is already defined as in the preceding code

# Set font properties
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf', size=20)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(f['num_features'], f['f1_scores_mean'], marker='o', linestyle='--', color='#189A80',linewidth=4,markersize=15)

# Set labels and title
plt.xlabel('Number of Features', fontproperties=myfont)
plt.ylabel('F1-Score', fontproperties=myfont)
plt.title('F1-Score vs. Number of Features', fontproperties=myfont)

# Customize ticks
plt.xticks(fontproperties=myfont)
plt.yticks(fontproperties=myfont)

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## ROC

# %%
roc=pd.read_csv('/content/drive/MyDrive/pgml/figure/roc_micro.csv')
roc
# Out:
#        fpr_micro  tpr_micro
# 0       0.000000   0.000000
# 1       0.000000   0.000203
# 2       0.000005   0.000203
# 3       0.000005   0.000811
# 4       0.000010   0.000811
# ...          ...        ...
# 19074   0.661022   0.972008
# 19075   0.661037   0.972008
# 19076   0.661043   0.972008
# 19077   0.661475   0.972008
# 19078   1.000000   1.000000
#
# [19079 rows x 2 columns]

# %%
roc2=pd.read_csv('/content/drive/MyDrive/pgml/figure/roc_data.csv')
roc2
# Out:
#             fpr       tpr
# 0      0.000000  0.033924
# 1      0.000767  0.034002
# 2      0.000768  0.037313
# 3      0.000769  0.039521
# 4      0.000769  0.039521
# ...         ...       ...
# 12431  0.997613  0.999179
# 12432  0.997627  0.999183
# 12433  0.998382  0.999434
# 12434  0.998383  0.999435
# 12435  1.000000  1.000000
#
# [12436 rows x 2 columns]

# %%
all_fpr=roc2['fpr']
mean_tpr=roc2['tpr']
roc_auc_macro=0.714430033095623
fpr_micro=roc['fpr_micro']
tpr_micro=roc['tpr_micro']
roc_auc_micro=0.8660162266099634

# %%
font=45
myfont = FontProperties(fname=r'/usr/local/lib/python3.10/dist-packages/matplotlib/mpl-data/fonts/ttf/Helvetica.ttf',size=font)
# Data


fig, ax = plt.subplots(figsize =(22, 15))
plt.plot(all_fpr, mean_tpr, label=f'Macro-averaged (AUC_ROC = {roc_auc_macro:.2f})',linestyle='-', linewidth=5,color='#189A80')
plt.plot(fpr_micro, tpr_micro, label=f'Micro-averaged (AUC_ROC = {roc_auc_micro:.2f})',linestyle='-', linewidth=5,color='#F09C2A')
plt.plot([0, 1], [0, 1], 'k--',linewidth=5)  # Diagonal line (random classifier)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks(fontproperties=myfont)
plt.xticks(fontproperties=myfont)
plt.xlabel('False Positive Rate',fontproperties=myfont)
plt.ylabel('True Positive Rate',fontproperties=myfont)
#plt.title('Receiver Operating Characteristic (ROC) Curve',fontproperties=myfont)
plt.legend(loc="lower right",prop=myfont)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=10)
ax.tick_params(which='minor', length=4)

ax.spines['bottom'].set_linewidth(4)
ax.spines['left'].set_linewidth(4)
ax.spines['right'].set_linewidth(4)
ax.spines['top'].set_linewidth(4)
plt.show()
